# %%
import sys
if 'google.colab' in sys.modules:
    import os

    # Undo the recent upgrade of importlib-metadata
    ## Thanks to @Mxhiu: https://stackoverflow.com/a/73932581/14473118
    os.system("pip install -q importlib-metadata==4.13.0")
    os.system('apt-get install -y xvfb')
    os.system('wget https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/xvfb -O ../xvfb')
    # Download `atari_wrappers.py` script from github
    os.system("wget https://raw.githubusercontent.com/Zhan21/Practical_RL/master/week06_policy_based/atari_wrappers.py")  ### commented one line
    # Download `env_batch.py` script from github
    os.system("wget https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/week06_policy_based/env_batch.py")
    # Download `runners.py` script from github
    os.system("wget https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/week06_policy_based/runners.py")
    
    os.system('apt-get install -y python-opengl ffmpeg')
    os.system('pip install pyglet==1.2.4')
    # Update the gym environment to be compatible with the atari environment.
    os.system('pip install gym[atari,accept-rom-license]==0.21.0')
    os.system('python -m pip install -U pygame --user')

    print('setup complete')

# XVFB will be launched if you run on a server
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'
# Out:
# setup complete
# Starting virtual X frame buffer: Xvfb.

# %% [markdown]
# # Implementing Advantage-Actor Critic (A2C)

# %% [markdown]
# In this notebook you will implement Advantage Actor Critic algorithm that trains on a batch of Atari 2600 environments running in parallel.
#
# Firstly, we will use environment wrappers implemented in file `atari_wrappers.py`. These wrappers preprocess observations (resize, grayscale, take max between frames, skip frames and stack them together) and rewards. Some of the wrappers help to reset the environment and pass `done` flag equal to `True` when agent dies.
# File `env_batch.py` includes implementation of `ParallelEnvBatch` class that allows to run multiple environments in parallel. To create an environment we can use `nature_dqn_env` function. Note that if you are using
# PyTorch and not using `tensorboardX` you will need to implement a wrapper that will log **raw** total rewards that the *unwrapped* environment returns and redefine the implemention of `nature_dqn_env` function here.

# %%
# !pip install gym[atari,accept-rom-license]==0.22.0  # 0.21.0 doesn't work
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gym[accept-rom-license,atari]==0.22.0
#   Downloading gym-0.22.0.tar.gz (631 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 KB 10.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from gym[accept-rom-license,atari]==0.22.0) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.10.0 in /usr/local/lib/python3.9/dist-packages (from gym[accept-rom-license,atari]==0.22.0) (4.13.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.9/dist-packages (from gym[accept-rom-license,atari]==0.22.0) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from gym[accept-rom-license,atari]==0.22.0) (2.2.1)
# Collecting ale-py~=0.7.4
#   Downloading ale_py-0.7.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.0 MB/s eta 0:00:00
# Collecting autorom[accept-rom-license]~=0.4.2
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.9/dist-packages (from ale-py~=0.7.4->gym[accept-rom-license,atari]==0.22.0) (5.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.22.0) (8.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.22.0) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.22.0) (4.65.0)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.0.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 KB 29.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.10.0->gym[accept-rom-license,atari]==0.22.0) (3.15.0)
# Collecting libtorrent
#   Downloading libtorrent-2.0.7-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 66.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.22.0) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.22.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.22.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]==0.22.0) (2022.12.7)
# Building wheels for collected packages: gym, AutoROM.accept-rom-license
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.22.0-py3-none-any.whl size=708396 sha256=9e35ae58c1ceffab5b7941d79c6751a942bb18e77d1d5b51ebc7d62f29683ebc
#   Stored in directory: /root/.cache/pip/wheels/c4/15/15/94c62e06887fb88768c5fa41482b80905ea71f3ede81040ffa
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.0-py3-none-any.whl size=446686 sha256=207e1232191429820ce4576b773e5d34cb43dc72eefcc0a0e2366d9f0642794b
#   Stored in directory: /root/.cache/pip/wheels/7d/17/c9/c31922a6aaf4ec7ec90eeee5dbc40ffbaafeda64b30a208b72
# Successfully built gym AutoROM.accept-rom-license
# Installing collected packages: libtorrent, gym, AutoROM.accept-rom-license, autorom, ale-py
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# Successfully installed AutoROM.accept-rom-license-0.6.0 ale-py-0.7.5 autorom-0.4.2 gym-0.22.0 libtorrent-2.0.7

# %%
import numpy as np
from atari_wrappers import nature_dqn_env, NumpySummaries

env = nature_dqn_env("SpaceInvadersNoFrameskip-v4", nenvs=8, summaries='Numpy')
obs = env.reset()
assert obs.shape == (8, 84, 84, 4)
assert obs.dtype == np.uint8

# %% [markdown]
# Next, we will need to implement a model that predicts logits and values. It is suggested that you use the same model as in [Nature DQN paper](https://web.stanford.edu/class/psych209/Readings/MnihEtAlHassibis15NatureControlDeepRL.pdf) with a modification that instead of having a single output layer, it will have two output layers taking as input the output of the last hidden layer. **Note** that this model is different from the model you used in homework where you implemented DQN. You can use your favorite deep learning framework here. We suggest that you use orthogonal initialization with parameter $\sqrt{2}$ for kernels and initialize biases with zeros.

# %%
import torch
from torch import nn

# %% [markdown]
# The input to
# the neural network consists of an 843 843 4 image produced by the preprocessing map w. The first hidden layer convolves 32 filters of 8 3 8 with stride 4with the
# input image and applies a rectifier nonlinearity31,32
# . The second hidden layer convolves 64 filters of 4 3 4 with stride 2, again followed by a rectifier nonlinearity.
# Thisisfollowed by a third convolutional layerthat convolves 64 filters of 3 3 3with
# stride 1 followed by a rectifier. The final hidden layer is fully-connected and consists of 512 rectifier units. The output layer is a fully-connected linear layer with a
# single output for each valid action. The number of valid actions varied between 4
# and 18 on the games we considered.

# %%
import torch
import torch.nn.functional as F
from torch import nn

# %%
class DQNAgent_1(nn.Module):
    def __init__(self, n_actions):

        super().__init__()
        self.n_actions = n_actions
        
        self.network = nn.Sequential(                    # in: 84x84
            nn.Conv2d(4, 32, kernel_size=8, stride=4),   # 20x20
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),  # 9x9
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),  # 7x7
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(7 * 7 * 64, 512),
            nn.ReLU()
        )
        
        self.pi_head = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, self.n_actions)
        )

        self.value_head = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 1)
        )
    
    def initialize_weights(m):
        if isinstance(m, nn.Conv2d):
            nn.init.orthogonal_(m.weight, np.sqrt(2))
            # if m.bias is not None:
            nn.init.zero_(m.bias)
        elif isinstance(m, nn.Linear):
            nn.init.zero_(m.bias)

    def forward(self, x):
        x = x / 255
        x = torch.Tensor(x).permute(0,3,1,2)
        x = self.network(x)
        pi = self.pi_head(x)
        value = self.value_head(x)
        return value, pi

# %%
class DQN(nn.Module):
  def __init__(self, ):
    super().__init__()
    self.ker = np.sqrt(2)

    self.conv1 = nn.Conv2d(4, 32, 8, stride = 4)
    nn.init.orthogonal_(self.conv1.weight, self.ker)
    self.conv1.bias.data.fill_(0.0)

    self.conv2 = nn.Conv2d(32,64, 4, stride = 2)
    nn.init.orthogonal_(self.conv2.weight, self.ker)
    self.conv2.bias.data.fill_(0.0)

    self.relu = nn.ReLU()

    self.conv3 = nn.Conv2d(64, 64, 3, stride = 1)
    nn.init.orthogonal_(self.conv3.weight, self.ker)
    self.conv3.bias.data.fill_(0.0)
    self.linear_hid = nn.Linear(3136, 512)
    nn.init.orthogonal_(self.linear_hid.weight, self.ker)
    self.linear_hid.bias.data.fill_(0.0)
    self.flatten = nn.Flatten()

    self.linear_hid_pi = nn.Linear(512, 512)
    nn.init.orthogonal_(self.linear_hid_pi.weight, self.ker)
    self.linear_hid_pi.bias.data.fill_(0.0)
    self.linear_out_pi = nn.Linear(512, env.action_space.n)
    nn.init.orthogonal_(self.linear_out_pi.weight, self.ker)
    self.linear_out_pi.bias.data.fill_(0.0)
    self.pi = nn.Sequential(
        self.linear_hid_pi,
        nn.ReLU(),
        self.linear_out_pi
    )

    self.linear_hid_value = nn.Linear(512, 512)
    nn.init.orthogonal_(self.linear_hid_value.weight, self.ker)
    self.linear_hid_value.bias.data.fill_(0.0)
    self.linear_out_value = nn.Linear(512, 1)
    nn.init.orthogonal_(self.linear_out_value.weight, self.ker)
    self.linear_out_value.bias.data.fill_(0.0)
    self.value = nn.Sequential(
        self.linear_hid_value,
        nn.ReLU(),
        self.linear_out_value
    )

  def forward(self, x):
    x = torch.Tensor(x).permute(0,3,1,2)
    x = self.relu(self.conv1(x))
    x = self.relu(self.conv2(x))
    x = self.relu(self.conv3(x))
    x = self.relu(self.linear_hid(self.flatten(x)))
    V = self.value(x)
    pi = self.pi(x)
    return V, pi

# %%
np.array()
# Out:
# tensor([1., 1.])

# %%
n_actions, n_envs = 6, 8
inputs = torch.rand([n_envs, 84, 84, 4])
model = DQNAgent_1(n_actions)
model.forward(inputs)
# Out:
# (tensor([[-0.0209],
#          [-0.0209],
#          [-0.0209],
#          [-0.0209],
#          [-0.0208],
#          [-0.0208],
#          [-0.0209],
#          [-0.0208]], grad_fn=<AddmmBackward0>),
#  tensor([[ 0.0212, -0.0090,  0.0114, -0.0517,  0.0275,  0.0083],
#          [ 0.0212, -0.0090,  0.0114, -0.0517,  0.0275,  0.0083],
#          [ 0.0212, -0.0090,  0.0114, -0.0517,  0.0274,  0.0083],
#          [ 0.0212, -0.0090,  0.0114, -0.0517,  0.0275,  0.0083],
#          [ 0.0212, -0.0090,  0.0114, -0.0517,  0.0275,  0.0083],
#          [ 0.0212, -0.0090,  0.0114, -0.0517,  0.0275,  0.0083],
#          [ 0.0212, -0.0090,  0.0114, -0.0517,  0.0275,  0.0083],
#          [ 0.0212, -0.0090,  0.0114, -0.0517,  0.0275,  0.0083]],
#         grad_fn=<AddmmBackward0>))

# %% [markdown]
# You will also need to define and use a policy that wraps the model. While the model computes logits for all actions, the policy will sample actions and also compute their log probabilities.  `policy.act` should return a dictionary of all the arrays that are needed to interact with an environment and train the model.
#  Note that actions must be an `np.ndarray` while the other
# tensors need to have the type determined by your deep learning framework.

# %%
class Policy_1:
    def __init__(self, model):
        self.model = model

    def act(self, inputs):
        # <Implement policy by calling model, sampling actions and computing their log probs>
        # Should return a dict containing keys ['actions', 'logits', 'log_probs', 'values'].
        dct = {}
        dct['values'], dct['logits'] = self.model(inputs)
        dct['probs'] = F.softmax(dct['logits'], 1)
        dct['log_probs'] = F.log_softmax(dct['logits'], 1)

        probs = dct['probs'].detach().numpy()
        chosen_actions = []
        for i in range(probs.shape[0]):
            chosen_actions.append(np.random.choice(probs.shape[1], p=probs[i]))
        dct['actions'] = np.array(chosen_actions)

        return dct

# %%
class Policy:
    def __init__(self, model):
        self.model = model
    def act(self, inputs):
        #<Implement policy by calling model, sampling actions and computing their log probs>
        # Should return a dict containing keys ['actions', 'logits', 'log_probs', 'values'].
        res = {}
        res['values'], res['logits'] = self.model(inputs)
        probs = nn.functional.softmax(res['logits'], -1)
        res['log_probs'] = nn.functional.log_softmax(res['logits'], -1)
        res['actions'] = []
        for i in range(probs.size(0)):
          res['actions'].append(
              np.random.choice(
                  env.action_space.n, p = probs[i].detach().numpy()
                  )
              )
        res['actions'] = np.array(res['actions'])
        return res

# %%
policy = Policy_1(DQNAgent_1(n_actions))
act = policy.act(inputs)
act
# Out:
# {'values': tensor([[0.0341],
#          [0.0341],
#          [0.0341],
#          [0.0341],
#          [0.0341],
#          [0.0341],
#          [0.0341],
#          [0.0341]], grad_fn=<AddmmBackward0>),
#  'logits': tensor([[ 0.0170, -0.0130, -0.0257, -0.0197,  0.0387, -0.0056],
#          [ 0.0170, -0.0130, -0.0257, -0.0197,  0.0387, -0.0056],
#          [ 0.0170, -0.0130, -0.0257, -0.0197,  0.0387, -0.0056],
#          [ 0.0170, -0.0130, -0.0257, -0.0197,  0.0387, -0.0056],
#          [ 0.0170, -0.0130, -0.0257, -0.0197,  0.0387, -0.0056],
#          [ 0.0170, -0.0130, -0.0257, -0.0197,  0.0387, -0.0056],
#          [ 0.0170, -0.0130, -0.0257, -0.0197,  0.0387, -0.0056],
#          [ 0.0170, -0.0130, -0.0257, -0.0197,  0.0387, -0.0056]],
#         grad_fn=<AddmmBackward0>),
#  'probs': tensor([[0.1697, 0.1647, 0.1626, 0.1636, 0.1734, 0.1659],
#          [0.1697, 0.1647, 0.1626, 0.1636, 0.1734, 0.1659],
#          [0.1697, 0.1647, 0.1626, 0.1636, 0.1734, 0.1659],
#          [0.1697, 0.1647, 0.1626, 0.1636, 0.1734, 0.1659],
#          [0.1697, 0.1647, 0.1626, 0.1636, 0.1734, 0.1659],
#          [0.1697, 0.1647, 0.1626, 0.1636, 0.1734, 0.1659],
#          [0.1697, 0.1647, 0.1626, 0.1636, 0.1734, 0.1659],
#          [0.1697, 0.1647, 0.1626, 0.1636, 0.1734, 0.1659]],
#         grad_fn=<SoftmaxBackward0>),
#  'log_probs': tensor([[-1.7736, -1.8036, -1.8163, -1.8104, -1.7520, -1.7962],
#          [-1.7736, -1.8036, -1.8163, -1.8104, -1.7519, -1.7962],
#          [-1.7736, -1.8036, -1.8163, -1.8104, -1.7519, -1.7962],
#          [-1.7736, -1.8036, -1.8163, -1.8104, -1.7519, -1.7962],
#          [-1.7736, -1.8036, -1.8163, -1.8104, -1.7519, -1.7962],
#          [-1.7736, -1.8036, -1.8163, -1.8104, -1.7520, -1.7962],
#          [-1.7736, -1.8036, -1.8163, -1.8103, -1.7519, -1.7962],
#          [-1.7736, -1.8036, -1.8163, -1.8104, -1.7520, -1.7962]],
#         grad_fn=<LogSoftmaxBackward0>),
#  'actions': array([3, 4, 3, 3, 4, 4, 1, 3])}

# %%
act['values'].shape
# Out:
# torch.Size([8, 1])

# %% [markdown]
# Next will pass the environment and policy to a runner that collects partial trajectories from the environment.
# The class that does is is already implemented for you.

# %%
from runners import EnvRunner

# %% [markdown]
# This runner interacts with the environment for a given number of steps and returns a dictionary containing
# keys
#
# * 'observations'
# * 'rewards'
# * 'resets'
# * 'actions'
# * all other keys that you defined in `Policy`
#
# under each of these keys there is a python `list` of interactions with the environment. This list has length $T$ that is size of partial trajectory. Partial trajectory for given moment `t` is part of `ComputeValueTargets.__call__` input argument `trajectory` from moment `t` to the end (i.e. it's different at each iteration in the algorithm).

# %% [markdown]
# To train the part of the model that predicts state values you will need to compute the value targets.
# Any callable could be passed to `EnvRunner` to be applied to each partial trajectory after it is collected.
# Thus, we can implement and use `ComputeValueTargets` callable.
# The formula for the value targets is simple:
#
# $$
# \hat v(s_t) = \left( \sum_{t'=0}^{T - 1} \gamma^{t'}r_{t+t'} \right) + \gamma^T \hat{v}(s_{t+T}),
# $$
#
# In implementation, however, do not forget to use
# `trajectory['resets']` flags to check if you need to add the value targets at the next step when
# computing value targets for the current step. You can access `trajectory['state']['latest_observation']`
# to get last observations in partial trajectory &mdash; $s_{t+T}$.

# %%
[0, 1, 2][-3]
# Out:
# 0

# %%
class ComputeValueTargets_1:  ### my realization
    def __init__(self, policy, gamma=0.99):
        self.policy = policy
        self.gamma = gamma

    def __call__(self, trajectory):
        # This method should modify trajectory inplace by adding
        # an item with key 'value_targets' to it.
        # <Compute value targets for a given partial trajectory>
        v_critic = self.policy.act(
                  trajectory['state']['latest_observation']
                  )['values']
        v_t = v_critic.detach().numpy().squeeze()  # [8,]
        value_targets = []
        n_steps = trajectory['state']['env_steps']
        
        for i in range(1, n_steps+1):
            v_t = trajectory['rewards'][-i] + self.gamma * v_t
            value_targets.append(v_t)

        trajectory['value_targets'] = value_targets[::-1]
        
        ### TODO: resets

# %%
class ComputeValueTargets:
    def __init__(self, policy, gamma=0.99):
        self.policy = policy
        self.gamma = gamma
    @torch.no_grad()
    def __call__(self, trajectory):
        # This method should modify trajectory inplace by adding
        # an item with key 'value_targets' to it.
        trajectory['value_targets'] = []
        # <Compute value targets for a given partial trajectory>
        n_steps = trajectory['state']['env_steps']
        for t in range(n_steps):
          v = 0
          for t_r in range(n_steps-t):
            if t_r + t == n_steps-1:
              v+= self.gamma**(t_r) * self.policy.act(
                  trajectory['state']['latest_observation']
                  )['values'].view(1,-1).squeeze().detach().numpy()
              break

            v+=self.gamma**(t_r)*trajectory['rewards'][t+t_r]
            if np.any(trajectory['resets'][t_r]):
              # v+= self.gamma**(t_r+1) * self.policy.act(
              #     trajectory['state']['latest_observation']
              #     )['values'].view(1,-1).squeeze().detach().numpy()
              break
          trajectory['value_targets'].append(v)

# %%
a=torch.rand([5])
b=torch.rand([5])
np.stack([a, b])
# Out:
# array([[0.36041033, 0.6215222 , 0.74961174, 0.30095887, 0.35326636],
#        [0.90799874, 0.31638306, 0.7753347 , 0.4027121 , 0.5963971 ]],
#       dtype=float32)

# %% [markdown]
# After computing value targets we will transform lists of interactions into tensors
# with the first dimension `batch_size` which is equal to `env_steps * nenvs`, i.e. you essentially need
# to flatten the first two dimensions.

# %%
class MergeTimeBatch:
    """ Merges first two axes typically representing time and env batch. """
    def __call__(self, trajectory):
        # Modify trajectory inplace.
        time = trajectory['state']['env_steps']
        shape = trajectory['observations'][0].shape
        env_batch = shape[0]
        for key in trajectory.keys():
          if key == 'observations':
            trajectory['observations'] = torch.Tensor(trajectory['observations']).view(time*env_batch, shape[1], shape[2], shape[3])
          elif key != 'state':
            if key in ['values', 'logits', 'log_probs']:
              trajectory[key] = torch.cat(trajectory[key])
            else:
              trajectory[key]  = torch.Tensor(trajectory[key]).view(time*env_batch, -1)

# %%
class MergeTimeBatch_1:  ### works with my functions
    """ Merges first two axes typically representing time and env batch. """
    def __call__(self, trajectory):
        # Modify trajectory inplace.
        env_steps = trajectory['state']['env_steps']
        nenvs = trajectory['actions'][0].shape[0]

        # observations
        obs = trajectory['observations']
        obs = np.stack(obs).reshape((env_steps*nenvs,) + obs[0].shape[1:])
        trajectory['observations'] = torch.Tensor(obs)

        for key in trajectory.keys():
          if key in ['values', 'logits', 'log_probs', 'probs']:  # gradients leaking
            trajectory[key] = torch.cat(trajectory[key], dim=0)

          elif key in ['actions', 'rewards', 'resets', 'value_targets']:
            trajectory[key]  = torch.Tensor(trajectory[key]).view(env_steps*nenvs, -1)

# %%
np.random.seed(100)
env = nature_dqn_env("SpaceInvadersNoFrameskip-v4", nenvs=8, summaries='Numpy')
env.action_space.n
# Out:
# 6

# %%
model = DQNAgent_1(env.action_space.n)
policy = Policy_1(model)

# %%
runner = EnvRunner(
    env, policy, nsteps=5,
    transforms=[
        ComputeValueTargets_1(policy),
        MergeTimeBatch_1()] #####
        )

# %%
trajectory["observations"][].max()
# Out:
# tensor(138.)

# %%
trajectory = runner.get_next()
trajectory.keys()
# Out:
# dict_keys(['actions', 'values', 'logits', 'probs', 'log_probs', 'observations', 'rewards', 'resets', 'state', 'value_targets'])

# %%
trajectory['log_probs'].shape
# Out:
# torch.Size([40, 6])

# %% [markdown]
# Now is the time to implement the advantage actor critic algorithm itself. You can look into your lecture,
# [Mnih et al. 2016](https://arxiv.org/abs/1602.01783) paper, and [lecture](https://www.youtube.com/watch?v=Tol_jw5hWnI&list=PLkFD6_40KJIxJMR-j5A1mkxK26gh_qg37&index=20) by Sergey Levine.

# %%
def to_one_hot(y_tensor, ndims):
    """ helper: take an integer vector and convert it to 1-hot matrix. """
    y_tensor = y_tensor.type(torch.LongTensor).view(-1, 1)
    y_one_hot = torch.zeros(
        y_tensor.size()[0], ndims).scatter_(1, y_tensor, 1)
    return y_one_hot

# %%
ohe = to_one_hot(trajectory['actions'], env.action_space.n)
(ohe > 0)[:3]
# Out:
# tensor([[False,  True, False, False, False, False],
#         [False, False, False, False,  True, False],
#         [False, False, False, False, False,  True]])

# %%
torch.sum(trajectory['log_probs'] * ohe, dim=1)
# Out:
# tensor([-1.7918, -1.8003, -2.0865, -2.0865, -1.5230, -1.8511, -1.5230, -1.5230,
#         -1.7918, -1.7918, -1.7788, -1.5230, -1.5230, -1.8511, -1.8511, -1.7788,
#         -2.0879, -2.0879, -1.8596, -1.5200, -1.5200, -1.7907, -1.7907, -1.7907,
#         -1.7974, -2.0864, -2.0864, -1.8520, -1.8008, -1.5232, -1.7718, -1.5232,
#         -1.5298, -1.7796, -1.5298, -2.0753, -1.5298, -1.5298, -1.7975, -1.7975],
#        grad_fn=<SumBackward1>)

# %%
- torch.mean((trajectory['log_probs'] * trajectory['log_probs']).sum(1))
# Out:
# tensor(-19.7115, grad_fn=<NegBackward0>)

# %%
class A2C:
    def __init__(self,
                 policy,
                 optimizer,
                 value_loss_coef=0.25,
                 entropy_coef=0.01,
                 max_grad_norm=0.5):
        self.policy = policy
        self.optimizer = optimizer
        self.value_loss_coef = value_loss_coef
        self.entropy_coef = entropy_coef
        self.max_grad_norm = max_grad_norm

    def policy_loss(self, trajectory):
        # You will need to compute advantages here.
        advantages = (trajectory['value_targets'] - trajectory['values'].detach())
        pi_loss =  -(trajectory['log_probs']*advantages).mean()
        return pi_loss

    def value_loss(self, trajectory):
        v_l1 = self.value_loss_coef * nn.functional.smooth_l1_loss(trajectory['value_targets'], trajectory['values'])
        return v_l1

    def loss(self, trajectory):
        entropy_loss = -self.entropy_coef*(trajectory['log_probs']*nn.functional.softmax(trajectory['logit'], dim=-1)).mean()
        pi_loss = self.policy_loss(trajectory)
        v_loss = self.value_loss(trajectory)
        l = pi_loss + v_loss - entropy_loss
        return l#, pi_loss.item(), v_loss.item(), entropy_loss.item()
    def step(self, trajectory):
        self.optimizer.zero_grad()
        l = self.loss(trajectory)
        l.backward()
        self.norm = nn.utils.clip_grad_norm_(policy.model.parameters(),
                                             self.max_grad_norm )
        self.optimizer.step()
        self.optimizer.zero_grad()

# %%
class A2C_1:
    def __init__(self,
                 policy,
                 optimizer,
                 value_loss_coef=0.25,
                 entropy_coef=0.01,
                 max_grad_norm=0.5):
        self.policy = policy
        self.optimizer = optimizer
        self.value_loss_coef = value_loss_coef
        self.entropy_coef = entropy_coef
        self.max_grad_norm = max_grad_norm

    @staticmethod
    def to_one_hot(y_tensor, ndims):
        """ helper: take an integer vector and convert it to 1-hot matrix. """
        y_tensor = y_tensor.type(torch.LongTensor).view(-1, 1)
        y_one_hot = torch.zeros(
            y_tensor.size()[0], ndims).scatter_(1, y_tensor, 1)
        return y_one_hot

    def policy_loss(self, trajectory):
        # You will need to compute advantages here.
        onehot_actions = to_one_hot(trajectory['actions'], env.action_space.n)

        log_probs_for_actions = trajectory['log_probs'][onehot_actions > 0].unsqueeze(1)  # [40, 1]
        advantages = (trajectory['value_targets'] - trajectory['values'].detach())  # [40, 1]

        pi_loss = -torch.mean(log_probs_for_actions * advantages)
        self.advantages = torch.mean(advantages)
        return pi_loss

    def value_loss(self, trajectory):
        return F.mse_loss(trajectory['value_targets'], trajectory['values'])

    def loss(self, trajectory):
        pi_loss = self.policy_loss(trajectory)
        v_loss = self.value_loss(trajectory)

        self.entropy = -torch.mean((trajectory['log_probs'] * trajectory['probs']).sum(1))

        main_loss = pi_loss + self.value_loss_coef * v_loss - self.entropy_coef * self.entropy
        return main_loss

    def step(self, trajectory):
        loss = self.loss(trajectory)
        loss.backward()

        self.grad_norm = nn.utils.clip_grad_norm_(policy.model.parameters(), self.max_grad_norm)
        self.optimizer.step()
        self.optimizer.zero_grad()

# %% [markdown]
# Now you can train your model. With reasonable hyperparameters training on a single GTX1080 for 10 million steps across all batched environments (which translates to about 5 hours of wall clock time)
# it should be possible to achieve *average raw reward over last 100 episodes* (the average is taken over 100 last
# episodes in each environment in the batch) of about 600. You should plot this quantity with respect to
# `runner.step_var` &mdash; the number of interactions with all environments. It is highly
# encouraged to also provide plots of the following quantities (these are useful for debugging as well):
#
# * [Coefficient of Determination](https://en.wikipedia.org/wiki/Coefficient_of_determination) between
# value targets and value predictions
# * Entropy of the policy $\pi$
# * Value loss
# * Policy loss
# * Value targets
# * Value predictions
# * Gradient norm
# * Advantages
# * A2C loss
#
# For optimization we suggest you use RMSProp with learning rate starting from 7e-4 and linearly decayed to 0, smoothing constant (alpha in PyTorch and decay in TensorFlow) equal to 0.99 and epsilon equal to 1e-5.

# %%
from collections import defaultdict
NumpySummaries._summaries = defaultdict(list)
NumpySummaries._summaries
# Out:
# defaultdict(list, {})

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt

env = nature_dqn_env("SpaceInvadersNoFrameskip-v4", nenvs=8, summaries='Numpy')

model = DQNAgent_1(6)
policy = Policy_1(model)
runner = EnvRunner(
    env, policy, nsteps=5,
    transforms=[
        ComputeValueTargets_1(policy),
        MergeTimeBatch_1()],
    )

optimizer = torch.optim.RMSprop(policy.model.parameters(), lr=7e-4, alpha=0.99, eps=1e-5)
a2c = A2C_1(policy, optimizer, value_loss_coef=0.25, entropy_coef=0.01, max_grad_norm=0.5)

# %%
num_epochs = 10**7

# def train(a2c, runner, policy, num_epochs=10**6):
for i in range(num_epochs):
    NumpySummaries.set_step(runner.step_var)  # update step_var

    trajectory = runner.get_next()  # generate session
    a2c.step(trajectory)            # gradient step

    env.add_summary_scalar('loss', a2c.loss(trajectory).item())
    env.add_summary_scalar('policy_loss', a2c.policy_loss(trajectory).item())
    env.add_summary_scalar('value_loss', a2c.value_loss(trajectory).item())
    env.add_summary_scalar('entropy', a2c.entropy.item())
    env.add_summary_scalar('advantages', a2c.advantages.item())
    env.add_summary_scalar('grad_norm', a2c.grad_norm.item())
    
    summary = ["SpaceInvadersNoFrameskip-v4/reward_mean_100", 
               "loss", "policy_loss", "value_loss", "entropy", "advantages", "grad_norm"]
    if i % 10 == 0:
        clear_output(True)
        fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))

        for ax, name in zip(axs.ravel(), summary):
            history = np.array(NumpySummaries.get_values(name))
            if len(history) > 0:
                print(name + ":\t" + f"{history[-1][1]}")
                
                ax.set_title(name)
                ax.set_xlabel("Steps")
                ax.plot(history[:, 0], history[:, 1])
                ax.grid()
        plt.show()
# train(a2c, runner, policy, num_epochs)
# Out:
# SpaceInvadersNoFrameskip-v4/reward_mean_100:	244.31875
# loss:	-0.08435100317001343
# policy_loss:	-0.08266480267047882
# value_loss:	0.0634978860616684
# entropy:	1.7560676336288452
# advantages:	-0.04455539584159851
# grad_norm:	0.2774597704410553

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))

for ax, name in zip(axs.ravel(), summary):
    ax.set_title(name)
    ax.grid()

# %%
history[-1]
plt.plot(history[:, 0], history[:, 1]);

# %%
a = np.array([(0, 10), (10, 20), [15, 60]])
print(a[-1])
plt.plot(a[:, 0], a[:, 1])
# Out:
# [15 60]

# %%
trajectory = runner.get_next()
trajectory.keys()
# Out:
# dict_keys(['actions', 'values', 'logits', 'log_probs', 'observations', 'rewards', 'resets', 'state', 'value_targets'])

# %%
trajectory["logits"].shape, trajectory["log_probs"].shape
# Out:
# (torch.Size([40, 6]), torch.Size([40, 6]))

# %%
traj["observations"].shape
# Out:
# torch.Size([40, 84, 84, 4])

# %%
traj["actions"].shape, traj["values"].shape, traj["rewards"].shape, traj["resets"].shape, traj["value_targets"].shape
# Out:
# (torch.Size([40, 1]),
#  torch.Size([40, 1]),
#  torch.Size([40, 1]),
#  torch.Size([40, 1]),
#  torch.Size([40, 1]))

# %%
traj["state"].keys()
# Out:
# dict_keys(['latest_observation', 'env_steps'])

# %%
traj["state"]["latest_observation"].shape, traj["state"]["env_steps"]
# Out:
# ((8, 84, 84, 4), 5)

# %%
NumpySummaries._summary_step
# Out:
# 1720

# %% [markdown]
# ### Target networks?
#
# You may recall a technique called "target networks" we used a few weeks ago when we trained a DQN agent to play Atari Breakout and wonder why we have not suggested using them here. The answer is that this is more historical than practical.
#
# While the "chasing the target" problem is still present in actor-critic value estimation and target networks do show up in follow-up papers, the original A3C/A2C papers do not mention them and do not explain this omission.
#
# The hypothesis why this may not be a big deal (compared to Q-learning) goes like this. An A3C/A2C agent selects actions based on policy, not an epsilon greedy exploration function, for which the argmax can change drastically due to tiny errors in function approximation. Therefore, errors in the value target caused by target chasing will cause less damage.
#
# Also, the actor-critic gradient relies on the advantage function $A(s_t, a_t) = Q(s_t, a_t) - V(s_t)$. Compare this to the $Q$-function $Q(s_t, a_t) = r(s_t, a_t) + \gamma \cdot \mathbb{E}_{s_{t+1} \mid s_t, a_t} V(s_{t+1})$ used in Q-learning and SARSA: we would expect that any bias in $V$-function approximation will be carried over from $V(s_{t+1})$ to $V(s_t)$ by gradient updates. However, in the formula for the advantage function the two approximations ($Q$-function and $V$-function) come with opposite signs, and thus the errors will cancel out.
#
# The last reason may be computational. Authors were concerned to beat existent algorithms in the wall-clock learning time, and any overhead of parameter copying (target network update) counted against this goal.
